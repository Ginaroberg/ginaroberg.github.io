# %%
import pandas as pd

# %%
uber = pd.read_csv('uber.csv')
uber = uber.drop(columns = 'Unnamed: 0')
uber
# Out:
#              Key                           date  fare_amount  \
# 0       24238194    2015-05-07 19:52:06.0000003          7.5
# 1       27835199    2009-07-17 20:04:56.0000002          7.7
# 2       44984355   2009-08-24 21:45:00.00000061         12.9
# 3       25894730    2009-06-26 08:22:21.0000001          5.3
# 4       17610152  2014-08-28 17:47:00.000000188         16.0
# ...          ...                            ...          ...
# 199995  42598914   2012-10-28 10:49:00.00000053          3.0
# 199996  16382965    2014-03-14 01:09:00.0000008          7.5
# 199997  27804658   2009-06-29 00:42:00.00000078         30.9
# 199998  20259894    2015-05-20 14:56:25.0000004         14.5
# 199999  11951496   2010-05-15 04:08:00.00000076         14.1
#
#         pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0             -73.999817        40.738354         -73.999512
# 1             -73.994355        40.728225         -73.994710
# ...

# %%
uber_lyft = pd.read_csv('cab_rides.csv')
uber_lyft
# Out:
#         distance cab_type     time_stamp    destination            source  \
# 0           0.44     Lyft  1544952607890  North Station  Haymarket Square
# 1           0.44     Lyft  1543284023677  North Station  Haymarket Square
# 2           0.44     Lyft  1543366822198  North Station  Haymarket Square
# 3           0.44     Lyft  1543553582749  North Station  Haymarket Square
# 4           0.44     Lyft  1543463360223  North Station  Haymarket Square
# ...          ...      ...            ...            ...               ...
# 693066      1.00     Uber  1543708385534      North End          West End
# 693067      1.00     Uber  1543708385534      North End          West End
# 693068      1.00     Uber  1543708385534      North End          West End
# 693069      1.00     Uber  1543708385534      North End          West End
# 693070      1.00     Uber  1543708385534      North End          West End
#
#         price  surge_multiplier                                    id  \
# ...

# %%
l2 = uber_lyft['destination'].unique().sort()

# %%
l1 = uber_lyft['source'].unique()

# %%
sorted(l1)
# Out:
# ['Back Bay',
#  'Beacon Hill',
#  'Boston University',
#  'Fenway',
#  'Financial District',
#  'Haymarket Square',
#  'North End',
#  'North Station',
#  'Northeastern University',
#  'South Station',
#  'Theatre District',
#  'West End']

# %%
l1 == l2
# Out:
# True

# %%
lat = {
     'Back Bay': 42.3495,
     'Beacon Hill':42.3562,
     'Boston University':42.3505,
     'Fenway':42.3467,
     'Financial District':40.7077,
     'Haymarket Square':42.3638,
     'North End':42.3652,
     'North Station':42.3664,
     'Northeastern University':42.3399,
     'South Station':42.3519
     'Theatre District':40.7590
     'West End':26.6867
    }
    
long = {
     'Back Bay': 71.0795,
     'Beacon Hill':71.0694,
     'Boston University':71.1054,
     'Fenway':71.0972,
     'Financial District':74.0083,
     'Haymarket Square':71.0585,
     'North End':71.0555,
     'North Station':71.0620,
     'Northeastern University': 71.0899,
     'South Station':71.0552
     'Theatre District':73.9845
     'West End':78.9712

    }

# %%
def latcoords(loc):
    lat = {
     'Back Bay': 42.3495,
     'Beacon Hill':42.3562,
     'Boston University':42.3505,
     'Fenway':42.3467,
     'Financial District':40.7077,
     'Haymarket Square':42.3638,
     'North End':42.3652,
     'North Station':42.3664,
     'Northeastern University':42.3399,
     'South Station':42.3519,
     'Theatre District':40.7590,
     'West End':26.6867
    }
    

    return lat[loc]

def longcoords(loc):
        long = {
         'Back Bay': -71.0795,
         'Beacon Hill':-71.0694,
         'Boston University':-71.1054,
         'Fenway':-71.0972,
         'Financial District':-74.0083,
         'Haymarket Square':-71.0585,
         'North End':-71.0555,
         'North Station':-71.0620,
         'Northeastern University': -71.0899,
         'South Station':-71.0552,
         'Theatre District':-73.9845,
         'West End':-78.9712

        }
        
        return long[loc]

# %%
uber_lyft['pickup_latitude'] = uber_lyft['source'].apply(latcoords)
uber_lyft['pickup_longitude'] = uber_lyft['source'].apply(longcoords)
uber_lyft['dropoff_latitude'] = uber_lyft['destination'].apply(latcoords)
uber_lyft['dropoff_longitude'] = uber_lyft['destination'].apply(longcoords)

# %%
uber_lyft.to_csv( 'cab_rides_new.csv', index = False)

# %%
uber_lyft
# Out:
#         distance cab_type     time_stamp    destination            source  \
# 0           0.44     Lyft  1544952607890  North Station  Haymarket Square
# 1           0.44     Lyft  1543284023677  North Station  Haymarket Square
# 2           0.44     Lyft  1543366822198  North Station  Haymarket Square
# 3           0.44     Lyft  1543553582749  North Station  Haymarket Square
# 4           0.44     Lyft  1543463360223  North Station  Haymarket Square
# ...          ...      ...            ...            ...               ...
# 693066      1.00     Uber  1543708385534      North End          West End
# 693067      1.00     Uber  1543708385534      North End          West End
# 693068      1.00     Uber  1543708385534      North End          West End
# 693069      1.00     Uber  1543708385534      North End          West End
# 693070      1.00     Uber  1543708385534      North End          West End
#
#         price  surge_multiplier                                    id  \
# ...

# %%
weather_df = pd.read_csv("weather.csv")
uber_df = pd.read_csv("uber.csv")
merged_df = pd.merge(uber_df, weather_df, left_on="Key", right_on="time_stamp", how="left")
merged_df.drop(["time_stamp"], axis=1, inplace=True)

# %%
merged_df
# Out:
#         Unnamed: 0       Key                           date  fare_amount  \
# 0                0  24238194    2015-05-07 19:52:06.0000003          7.5
# 1                1  27835199    2009-07-17 20:04:56.0000002          7.7
# 2                2  44984355   2009-08-24 21:45:00.00000061         12.9
# 3                3  25894730    2009-06-26 08:22:21.0000001          5.3
# 4                4  17610152  2014-08-28 17:47:00.000000188         16.0
# ...            ...       ...                            ...          ...
# 199995      199995  42598914   2012-10-28 10:49:00.00000053          3.0
# 199996      199996  16382965    2014-03-14 01:09:00.0000008          7.5
# 199997      199997  27804658   2009-06-29 00:42:00.00000078         30.9
# 199998      199998  20259894    2015-05-20 14:56:25.0000004         14.5
# 199999      199999  11951496   2010-05-15 04:08:00.00000076         14.1
#
#         pickup_longitude  pickup_latitude  dropoff_longitude  \
# ...

# %%
uber_df
# Out:
#         Unnamed: 0       Key                           date  fare_amount  \
# 0                0  24238194    2015-05-07 19:52:06.0000003          7.5
# 1                1  27835199    2009-07-17 20:04:56.0000002          7.7
# 2                2  44984355   2009-08-24 21:45:00.00000061         12.9
# 3                3  25894730    2009-06-26 08:22:21.0000001          5.3
# 4                4  17610152  2014-08-28 17:47:00.000000188         16.0
# ...            ...       ...                            ...          ...
# 199995      199995  42598914   2012-10-28 10:49:00.00000053          3.0
# 199996      199996  16382965    2014-03-14 01:09:00.0000008          7.5
# 199997      199997  27804658   2009-06-29 00:42:00.00000078         30.9
# 199998      199998  20259894    2015-05-20 14:56:25.0000004         14.5
# 199999      199999  11951496   2010-05-15 04:08:00.00000076         14.1
#
#         pickup_longitude  pickup_latitude  dropoff_longitude  \
# ...

# %%
import pandas as pd

# Read the weather CSV into a DataFrame
weather_df = pd.read_csv("weather.csv")

# Convert the timestamp column to datetime format
weather_df["time_stamp"] = pd.to_datetime(weather_df["time_stamp"], unit="s")

# Extract only the date from the timestamp
weather_df["date"] = weather_df["time_stamp"].dt.date

weather_df
# Out:
#        temp                 location  clouds  pressure    rain  \
# 0     42.42                 Back Bay    1.00   1012.14  0.1228
# 1     42.43              Beacon Hill    1.00   1012.15  0.1846
# 2     42.50        Boston University    1.00   1012.15  0.1089
# 3     42.11                   Fenway    1.00   1012.13  0.0969
# 4     43.13       Financial District    1.00   1012.14  0.1786
# ...     ...                      ...     ...       ...     ...
# 6271  44.72            North Station    0.89   1000.69     NaN
# 6272  44.85  Northeastern University    0.88   1000.71     NaN
# 6273  44.82            South Station    0.89   1000.70     NaN
# 6274  44.78         Theatre District    0.89   1000.70     NaN
# 6275  44.69                 West End    0.89   1000.70     NaN
#
#               time_stamp  humidity   wind        date
# 0    2018-12-16 23:45:01      0.77  11.25  2018-12-16
# 1    2018-12-16 23:45:01      0.76  11.32  2018-12-16
# ...

# %%
import pandas as pd

# Read the Uber CSV into a DataFrame
uber_df = pd.read_csv("uber.csv")

# Convert the timestamp column to datetime format
uber_df["date"] = pd.to_datetime(uber_df["date"])

# Extract only the date from the timestamp
uber_df["date"] = uber_df["date"].dt.date

# Print the updated DataFrame
uber_df
# Out:
#         Unnamed: 0       Key        date  fare_amount  pickup_longitude  \
# 0                0  24238194  2015-05-07          7.5        -73.999817
# 1                1  27835199  2009-07-17          7.7        -73.994355
# 2                2  44984355  2009-08-24         12.9        -74.005043
# 3                3  25894730  2009-06-26          5.3        -73.976124
# 4                4  17610152  2014-08-28         16.0        -73.925023
# ...            ...       ...         ...          ...               ...
# 199995      199995  42598914  2012-10-28          3.0        -73.987042
# 199996      199996  16382965  2014-03-14          7.5        -73.984722
# 199997      199997  27804658  2009-06-29         30.9        -73.986017
# 199998      199998  20259894  2015-05-20         14.5        -73.997124
# 199999      199999  11951496  2010-05-15         14.1        -73.984395
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count
# ...

# %%
merged_df = pd.merge(uber_df, weather_df, left_on="date", right_on="date", how="left")

merged_df
# Out:
#         Unnamed: 0       Key        date  fare_amount  pickup_longitude  \
# 0                0  24238194  2015-05-07          7.5        -73.999817
# 1                1  27835199  2009-07-17          7.7        -73.994355
# 2                2  44984355  2009-08-24         12.9        -74.005043
# 3                3  25894730  2009-06-26          5.3        -73.976124
# 4                4  17610152  2014-08-28         16.0        -73.925023
# ...            ...       ...         ...          ...               ...
# 199995      199995  42598914  2012-10-28          3.0        -73.987042
# 199996      199996  16382965  2014-03-14          7.5        -73.984722
# 199997      199997  27804658  2009-06-29         30.9        -73.986017
# 199998      199998  20259894  2015-05-20         14.5        -73.997124
# 199999      199999  11951496  2010-05-15         14.1        -73.984395
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# ...

# %%
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Key, date, fare_amount, pickup_longitude, pickup_latitude, dropoff_longitude, dropoff_latitude, passenger_count, temp, location, clouds, pressure, rain, humidity, wind]
# Index: []
